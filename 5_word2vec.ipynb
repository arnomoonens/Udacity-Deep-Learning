# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
from urllib import request
import zipfile
from matplotlib import pylab
from sklearn.manifold import TSNE
# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return f.read(name).split()
  f.close()
  
words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5244, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
data
# Out:
# [5244,
#  3082,
#  12,
#  6,
#  195,
#  2,
#  3136,
#  46,
#  59,
#  156,
#  128,
#  742,
#  477,
#  10592,
#  134,
#  1,
#  27403,
#  2,
#  1,
#  103,
#  855,
#  3,
#  1,
#  15120,
#  0,
#  2,
#  1,
#  151,
#  855,
#  3583,
#  1,
#  195,
#  11,
#  191,
#  59,
#  5,
#  6,
#  10768,
#  215,
#  7,
#  1326,
#  105,
#  455,
#  20,
#  59,
#  2732,
#  363,
#  7,
#  3679,
#  1,
#  709,
#  2,
#  372,
#  27,
#  41,
#  37,
#  54,
#  540,
#  98,
#  12,
#  6,
#  1424,
#  2759,
#  19,
#  568,
#  687,
#  7096,
#  1,
#  248,
#  5244,
#  11,
#  1053,
#  28,
#  1,
#  321,
#  249,
#  45045,
#  2880,
#  793,
#  187,
#  5244,
#  12,
#  6,
#  201,
#  603,
#  11,
#  1,
#  1137,
#  20,
#  2622,
#  26,
#  8995,
#  3,
#  280,
#  32,
#  4151,
#  142,
#  60,
#  26,
#  6446,
#  4188,
#  2,
#  154,
#  33,
#  363,
#  5244,
#  37,
#  1138,
#  7,
#  448,
#  346,
#  1819,
#  20,
#  4861,
#  1,
#  6773,
#  2,
#  7587,
#  1776,
#  567,
#  1,
#  94,
#  1,
#  248,
#  11107,
#  12,
#  52,
#  7096,
#  90,
#  27,
#  271,
#  38,
#  5961,
#  4873,
#  20430,
#  29,
#  0,
#  42,
#  318,
#  6,
#  26039,
#  528,
#  7587,
#  372,
#  5,
#  259,
#  2,
#  154,
#  26,
#  1207,
#  12,
#  7587,
#  201,
#  1577,
#  3,
#  15248,
#  333,
#  1776,
#  7096,
#  4861,
#  346,
#  765,
#  161,
#  407,
#  5703,
#  756,
#  2,
#  4110,
#  1132,
#  4338,
#  1537,
#  3,
#  568,
#  8140,
#  99,
#  5244,
#  11,
#  52,
#  1409,
#  687,
#  19,
#  154,
#  27,
#  11,
#  156,
#  7096,
#  37,
#  2036,
#  1424,
#  8195,
#  2,
#  154,
#  47,
#  695,
#  7,
#  32,
#  6,
#  4156,
#  247,
#  372,
#  77,
#  949,
#  79,
#  311,
#  31,
#  4786,
#  372,
#  508,
#  140,
#  2314,
#  3559,
#  365,
#  24,
#  1824,
#  7,
#  1903,
#  60,
#  11,
#  37,
#  8412,
#  79,
#  311,
#  6,
#  247,
#  372,
#  508,
#  32,
#  754,
#  79,
#  1733,
#  3,
#  8073,
#  24182,
#  3,
#  276,
#  1694,
#  20,
#  152,
#  1034,
#  96,
#  226,
#  372,
#  18,
#  1816,
#  25,
#  4786,
#  1557,
#  52,
#  8131,
#  1466,
#  24182,
#  3,
#  12793,
#  5,
#  6132,
#  20,
#  4191,
#  21290,
#  2428,
#  40,
#  16544,
#  3,
#  7240,
#  862,
#  2,
#  1195,
#  10264,
#  2515,
#  29,
#  15178,
#  188,
#  3,
#  49,
#  1124,
#  913,
#  7,
#  1050,
#  468,
#  12304,
#  7096,
#  134,
#  1,
#  1,
#  11107,
#  3057,
#  3,
#  12090,
#  735,
#  4786,
#  6619,
#  5,
#  14750,
#  28,
#  451,
#  486,
#  24182,
#  199,
#  296,
#  949,
#  5,
#  20046,
#  20331,
#  2,
#  0,
#  301,
#  7,
#  24182,
#  20331,
#  16618,
#  1,
#  30775,
#  2,
#  1,
#  94,
#  45,
#  3834,
#  3,
#  0,
#  3,
#  3808,
#  1,
#  3414,
#  2,
#  1,
#  1778,
#  188,
#  2,
#  1,
#  627,
#  1,
#  13150,
#  2,
#  4,
#  22,
#  91,
#  123,
#  285,
#  26,
#  244,
#  233,
#  7,
#  32,
#  437,
#  26462,
#  2,
#  174,
#  5244,
#  7732,
#  2536,
#  5,
#  30,
#  96,
#  2,
#  290,
#  603,
#  4311,
#  20,
#  1,
#  13150,
#  16618,
#  50,
#  188,
#  118,
#  47,
#  360,
#  20,
#  1,
#  385,
#  243,
#  97,
#  32,
#  5242,
#  35,
#  332,
#  2725,
#  19,
#  1,
#  839,
#  1379,
#  28,
#  33,
#  8777,
#  47,
#  6483,
#  35,
#  3246,
#  1,
#  27403,
#  29,
#  552,
#  43967,
#  40,
#  31,
#  128,
#  0,
#  436,
#  85,
#  1,
#  65,
#  2,
#  1,
#  103,
#  463,
#  84,
#  3,
#  26,
#  233,
#  19,
#  48,
#  12,
#  26462,
#  2,
#  174,
#  5244,
#  5,
#  1,
#  174,
#  840,
#  1,
#  46,
#  7,
#  90,
#  1,
#  195,
#  7,
#  1016,
#  1044,
#  43,
#  70,
#  4873,
#  18,
#  937,
#  15039,
#  4574,
#  165,
#  0,
#  5,
#  30,
#  42380,
#  11905,
#  23146,
#  260,
#  1226,
#  0,
#  0,
#  4,
#  23,
#  8,
#  17,
#  100,
#  36,
#  629,
#  1,
#  2665,
#  64,
#  372,
#  34,
#  49,
#  76,
#  94,
#  688,
#  14916,
#  4051,
#  29,
#  819,
#  918,
#  12,
#  102,
#  5,
#  11107,
#  2536,
#  363,
#  6,
#  6056,
#  3,
#  664,
#  5,
#  1,
#  64,
#  702,
#  436,
#  41,
#  4220,
#  1290,
#  20,
#  36,
#  11,
#  31,
#  4786,
#  3,
#  95,
#  26,
#  50,
#  30,
#  5227,
#  5,
#  4,
#  23,
#  9,
#  17,
#  5,
#  1,
#  5351,
#  2,
#  1,
#  151,
#  855,
#  468,
#  12304,
#  335,
#  31,
#  17196,
#  2435,
#  201,
#  1294,
#  142,
#  12304,
#  216,
#  38,
#  90,
#  1,
#  248,
#  5244,
#  56,
#  117,
#  7096,
#  39,
#  1207,
#  33,
#  198,
#  12,
#  1,
#  46,
#  182,
#  4786,
#  530,
#  3,
#  12304,
#  12,
#  1,
#  1836,
#  2,
#  1915,
#  5244,
#  42,
#  35,
#  33,
#  229,
#  76,
#  4786,
#  436,
#  734,
#  2400,
#  3,
#  1,
#  195,
#  0,
#  18,
#  87,
#  1074,
#  12,
#  31,
#  14060,
#  30262,
#  19,
#  1,
#  12119,
#  0,
#  35,
#  51,
#  2423,
#  617,
#  5,
#  1,
#  151,
#  855,
#  1,
#  46,
#  568,
#  8718,
#  4786,
#  2939,
#  1033,
#  14536,
#  27,
#  11,
#  637,
#  360,
#  20,
#  27,
#  5390,
#  155,
#  192,
#  2939,
#  1033,
#  14536,
#  335,
#  154,
#  11,
#  918,
#  5,
#  4,
#  13,
#  21,
#  8,
#  20,
#  1,
#  195,
#  4786,
#  18,
#  991,
#  12,
#  6,
#  568,
#  1609,
#  27,
#  11,
#  14,
#  33,
#  891,
#  20,
#  48,
#  849,
#  14536,
#  12,
#  1,
#  1836,
#  2,
#  174,
#  4786,
#  209,
#  5,
#  154,
#  11,
#  918,
#  14536,
#  5472,
#  24,
#  1,
#  420,
#  12993,
#  918,
#  11,
#  6899,
#  5,
#  33,
#  140,
#  36,
#  1347,
#  1,
#  2878,
#  2,
#  15178,
#  918,
#  0,
#  155,
#  100,
#  3466,
#  39,
#  653,
#  446,
#  7,
#  90,
#  3,
#  3136,
#  44,
#  918,
#  12,
#  47,
#  3598,
#  55,
#  12,
#  15414,
#  1556,
#  14,
#  2967,
#  5,
#  45,
#  259,
#  14536,
#  1166,
#  154,
#  36,
#  89,
#  3222,
#  1132,
#  53,
#  39,
#  752,
#  446,
#  7,
#  90,
#  1050,
#  523,
#  3,
#  1793,
#  5,
#  5825,
#  24,
#  1557,
#  2,
#  5129,
#  3,
#  1294,
#  14536,
#  15,
#  2655,
#  2,
#  11107,
#  34,
#  36,
#  89,
#  29777,
#  0,
#  967,
#  31,
#  1335,
#  519,
#  100,
#  1132,
#  3,
#  309,
#  160,
#  513,
#  1,
#  808,
#  2,
#  44,
#  1259,
#  219,
#  1259,
#  1038,
#  34,
#  1392,
#  1,
#  909,
#  2,
#  742,
#  65,
#  967,
#  5,
#  443,
#  33,
#  74,
#  2916,
#  20,
#  76,
#  4,
#  74,
#  2967,
#  28,
#  1,
#  1259,
#  2,
#  276,
#  1556,
#  160,
#  4322,
#  2519,
#  499,
#  5,
#  728,
#  10669,
#  18947,
#  31,
#  763,
#  247,
#  987,
#  74,
#  32,
#  178,
#  98,
#  7,
#  741,
#  3274,
#  24,
#  913,
#  7,
#  1,
#  363,
#  2,
#  443,
#  14536,
#  15,
#  949,
#  40,
#  2026,
#  223,
#  151,
#  742,
#  477,
#  1819,
#  3,
#  30,
#  2987,
#  40,
#  1023,
#  5,
#  1,
#  855,
#  2,
#  4,
#  13,
#  21,
#  13,
#  5,
#  303,
#  14536,
#  15,
#  603,
#  2,
#  918,
#  11,
#  648,
#  27,
#  18,
#  348,
#  5,
#  6,
#  113,
#  2,
#  312,
#  80,
#  30,
#  3570,
#  3,
#  60,
#  26,
#  6446,
#  4188,
#  2,
#  48,
#  2,
#  30,
#  949,
#  14,
#  51,
#  2161,
#  1591,
#  68,
#  622,
#  2753,
#  26281,
#  15,
#  15680,
#  5,
#  30,
#  1,
#  10508,
#  3,
#  45,
#  200,
#  26281,
#  1461,
#  20,
#  52,
#  637,
#  1047,
#  346,
#  1776,
#  134,
#  1,
#  2585,
#  2,
#  94,
#  918,
#  12,
#  6,
#  245,
#  390,
#  446,
#  5,
#  153,
#  3,
#  1,
#  148,
#  2585,
#  2,
#  372,
#  40,
#  4582,
#  20951,
#  29,
#  9226,
#  5,
#  1,
#  941,
#  1977,
#  2,
#  372,
#  20,
#  1,
#  1132,
#  26,
#  45,
#  1730,
#  36,
#  5230,
#  15680,
#  3,
#  6,
#  144,
#  2,
#  0,
#  5,
#  34,
#  1132,
#  74,
#  9732,
#  5,
#  5826,
#  2,
#  0,
#  67,
#  62,
#  27,
#  18,
#  5,
#  44,
#  568,
#  763,
#  7,
#  176,
#  95,
#  14,
#  119,
#  918,
#  685,
#  1146,
#  79,
#  124,
#  508,
#  13078,
#  5578,
#  311,
#  7,
#  370,
#  7,
#  4114,
#  1,
#  1799,
#  7,
#  119,
#  5473,
#  918,
#  3,
#  154,
#  72,
#  39,
#  5,
#  609,
#  184,
#  20,
#  11,
#  609,
#  200,
#  95,
#  185,
#  12,
#  72,
#  6208,
#  9037,
#  12,
#  7189,
#  72,
#  1226,
#  1,
#  34487,
#  2,
#  1,
#  1799,
#  26281,
#  364,
#  89,
#  392,
#  31,
#  4786,
#  36,
#  1047,
#  67,
#  1,
#  2759,
#  42526,
#  2072,
#  30,
#  949,
#  40,
#  2026,
#  25,
#  56,
#  0,
#  9969,
#  7096,
#  142,
#  4188,
#  2,
#  30,
#  502,
#  26,
#  3238,
#  ...]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(int(batch_size / num_skips)):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], '->', labels[i, 0])
  print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
print(labels)
# Out:
# 3679 -> 7
# b'destroy' -> b'to'
# 3679 -> 1
# b'destroy' -> b'the'
# 1 -> 709
# b'the' -> b'organization'
# 1 -> 3679
# b'the' -> b'destroy'
# 709 -> 2
# b'organization' -> b'of'
# 709 -> 1
# b'organization' -> b'the'
# 2 -> 709
# b'of' -> b'organization'
# 2 -> 372
# b'of' -> b'society'
# [[   7]
#  [   1]
#  [ 709]
#  [3679]
#  [   2]
#  [   1]
#  [ 709]
#  [ 372]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step", step, ":", average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = "Nearest to %s:" % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = "%s %s," % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0 : 7.67372655869
# Nearest to b'a': b'conclude', b'florentines', b'harbin', b'marxist', b'bilateral', b'topped', b'hamburgers', b'cosby',
# Nearest to b'he': b'sailors', b'sweetness', b'transmitters', b'hampton', b'dimethyl', b'fdp', b'hedeby', b'brooke',
# Nearest to b'about': b'cle', b'authorization', b'tb', b'counterclockwise', b'invariably', b'dramatic', b'mckay', b'warbird',
# Nearest to b'has': b'epiphany', b'sql', b'goofy', b'pillow', b'humanism', b'gumby', b'jost', b'engels',
# Nearest to b'was': b'climb', b'exemption', b'transmits', b'xl', b'misskelley', b'cottage', b'niles', b'imagines',
# Nearest to b'b': b'nationally', b'pokes', b'hayao', b'kept', b'wilhelmina', b'pocketing', b'arch', b'birthrate',
# Nearest to b'an': b'shrine', b'steiger', b'alliterative', b'canonized', b'pairing', b'coliseum', b'janissaries', b'stirring',
# Nearest to b'history': b'quattro', b'ladder', b'harcourt', b'undertones', b'found', b'inequality', b'mithras', b'lakes',
# Nearest to b'to': b'discharge', b'auctions', b'forum', b'ct', b'inoculated', b'tougher', b'hotly', b'urartu',
# Nearest to b'may': b'etymology', b'longsword', b'repeater', b'derogatory', b'ifs', b'operas', b'gammu', b'prairie',
# Nearest to b'for': b'platters', b'angli', b'mongoloid', b'landform', b'donner', b'bias', b'leste', b'goldberg',
# Nearest to b'some': b'passers', b'engraved', b'crusades', b'honshu', b'ralston', b'patent', b'commands', b'wasteland',
# Nearest to b'th': b'noradrenaline', b'adhered', b'trustees', b'panda', b'resolving', b'fated', b'basslines', b'guti',
# Nearest to b'more': b'akiva', b'microkernels', b'courland', b'meleon', b'twinning', b'anymore', b'francois', b'sapir',
# Nearest to b'eight': b'eisenhower', b'steroids', b'amon', b'strafford', b'zy', b'emile', b'serpentine', b'advanced',
# Nearest to b'if': b'franconia', b'playboys', b'chests', b'milit', b'cooking', b'bosniaks', b'recoil', b'biting',
# Average loss at step 2000 : 4.36096041256
# Average loss at step 4000 : 3.87027555487
# Average loss at step 6000 : 3.7892434082
# Average loss at step 8000 : 3.6842881043
# Average loss at step 10000 : 3.61785975373
# Nearest to b'a': b'the', b'toc', b'crouch', b'wounding', b'this', b'belize', b'its', b'fluorine',
# Nearest to b'he': b'it', b'she', b'they', b'who', b'anchoring', b'and', b'there', b'mizrahi',
# Nearest to b'about': b'nagano', b'li', b'militare', b'gottlob', b'dramatic', b'maquis', b'originally', b'sculpture',
# Nearest to b'has': b'had', b'was', b'is', b'have', b'engels', b'goofy', b'midrashic', b'hoe',
# Nearest to b'was': b'is', b'by', b'has', b'were', b'had', b'are', b'be', b'consubstantiation',
# Nearest to b'b': b'nationally', b'procurator', b'radiocommunication', b'zvi', b'christoph', b'arch', b'fused', b'roasting',
# Nearest to b'an': b'the', b'vpi', b'dassault', b'alliterative', b'stirring', b'yacht', b'loaded', b'codepages',
# Nearest to b'history': b'ladder', b'lakes', b'durian', b'quattro', b'undertones', b'both', b'harcourt', b'mithras',
# Nearest to b'to': b'discharge', b'auctions', b'not', b'tougher', b'urartu', b'aguilera', b'counselors', b'gordie',
# Nearest to b'may': b'etymology', b'can', b'derogatory', b'sousa', b'would', b'interprets', b'longsword', b'catenary',
# Nearest to b'for': b'with', b'raccoon', b'hunchback', b'of', b'in', b'sor', b'tyranny', b'and',
# Nearest to b'some': b'commands', b'passers', b'athletics', b'many', b'bitnet', b'patent', b'azeotrope', b'exposes',
# Nearest to b'th': b'four', b'three', b'noradrenaline', b'seven', b'five', b'botswana', b'panda', b'adhered',
# Nearest to b'more': b'rather', b'bitnet', b'codebreaking', b'courland', b'ascribes', b'model', b'disagreement', b'owned',
# Nearest to b'eight': b'nine', b'seven', b'six', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'where', b'ez', b'franconia', b'sigmund', b'poorer', b'eras', b'lethal', b'bulb',
# Average loss at step 12000 : 3.60337245035
# Average loss at step 14000 : 3.56806301475
# Average loss at step 16000 : 3.41157510179
# Average loss at step 18000 : 3.45423586893
# Average loss at step 20000 : 3.53906369734
# Nearest to b'a': b'the', b'crouch', b'enriched', b'fluorine', b'another', b'this', b'belize', b'scheduler',
# Nearest to b'he': b'it', b'she', b'they', b'who', b'there', b'rustic', b'creighton', b'mizrahi',
# Nearest to b'about': b'li', b'nagano', b'aha', b'militare', b'cle', b'realaudio', b'liberalised', b'virgins',
# Nearest to b'has': b'had', b'was', b'have', b'is', b'engels', b'drip', b'kilmer', b'goofy',
# Nearest to b'was': b'is', b'were', b'has', b'had', b'does', b'became', b'been', b'infectious',
# Nearest to b'b': b'd', b'procurator', b'unpredictable', b'onions', b'osce', b'shining', b'knuckles', b'mindstorms',
# Nearest to b'an': b'dassault', b'janissaries', b'the', b'alliterative', b'vpi', b'amicable', b'vectorborne', b'musket',
# Nearest to b'history': b'ladder', b'series', b'aar', b'undertones', b'costanza', b'lakes', b'mithras', b'quattro',
# Nearest to b'to': b'discharge', b'would', b'will', b'tested', b'tougher', b'ts', b'not', b'can',
# Nearest to b'may': b'can', b'would', b'should', b'will', b'might', b'could', b'must', b'sousa',
# Nearest to b'for': b'by', b'with', b'and', b'like', b'in', b'from', b'mag', b'of',
# Nearest to b'some': b'many', b'their', b'several', b'most', b'bitnet', b'these', b'all', b'other',
# Nearest to b'th': b'noradrenaline', b'five', b'four', b'culver', b'tran', b'botswana', b'one', b'fdp',
# Nearest to b'more': b'rather', b'less', b'very', b'most', b'disagreement', b'bitnet', b'parades', b'puente',
# Nearest to b'eight': b'seven', b'nine', b'six', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'where', b'but', b'does', b'ez', b'franconia', b'is', b'sigmund', b'though',
# Average loss at step 22000 : 3.50717915791
# Average loss at step 24000 : 3.48730536276
# Average loss at step 26000 : 3.47953561902
# Average loss at step 28000 : 3.48174940503
# Average loss at step 30000 : 3.50183872885
# Nearest to b'a': b'the', b'any', b'traceable', b'panyu', b'their', b'every', b'belize', b'another',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'there', b'mizrahi', b'rustic', b'clifton',
# Nearest to b'about': b'aha', b'li', b'around', b'leaving', b'militare', b'liberalised', b'shrapnel', b'accustomed',
# Nearest to b'has': b'had', b'have', b'was', b'is', b'engels', b'nativity', b'having', b'kilmer',
# Nearest to b'was': b'is', b'had', b'has', b'were', b'became', b'been', b'when', b'being',
# Nearest to b'b': b'd', b'procurator', b'unpredictable', b'chlamydia', b'braintree', b'whirlpool', b'mindstorms', b'neutron',
# Nearest to b'an': b'dassault', b'modified', b'erudite', b'musket', b'warrington', b'vectorborne', b'stirring', b'amicable',
# Nearest to b'history': b'ladder', b'series', b'aar', b'depopulation', b'antiquity', b'costanza', b'undertones', b'amount',
# Nearest to b'to': b'discharge', b'consular', b'will', b'would', b'can', b'could', b'verizon', b'cnidarians',
# Nearest to b'may': b'can', b'would', b'should', b'will', b'could', b'must', b'might', b'sousa',
# Nearest to b'for': b'of', b'with', b'formant', b'hunchback', b'inject', b'from', b'although', b'by',
# Nearest to b'some': b'many', b'these', b'several', b'most', b'all', b'their', b'athletics', b'both',
# Nearest to b'th': b'six', b'noradrenaline', b'eight', b'culver', b'zero', b'fdp', b'one', b'ogre',
# Nearest to b'more': b'less', b'rather', b'very', b'most', b'greater', b'kashubians', b'parades', b'bitnet',
# Nearest to b'eight': b'nine', b'six', b'seven', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'where', b'when', b'though', b'but', b'although', b'is', b'since', b'does',
# Average loss at step 32000 : 3.50018767613
# Average loss at step 34000 : 3.49736543202
# Average loss at step 36000 : 3.45259488523
# Average loss at step 38000 : 3.3051482054
# Average loss at step 40000 : 3.42740669787
# Nearest to b'a': b'the', b'another', b'customarily', b'guericke', b'fridays', b'b', b'boris', b'havenco',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'there', b'but', b'creighton', b'i',
# Nearest to b'about': b'around', b'aha', b'virgins', b'downstream', b'liberalised', b'road', b'textbooks', b'altimeter',
# Nearest to b'has': b'had', b'have', b'was', b'is', b'superstar', b'asin', b'drinking', b'nativity',
# Nearest to b'was': b'is', b'has', b'became', b'had', b'were', b'consubstantiation', b'been', b'does',
# Nearest to b'b': b'd', b'ruinous', b'osce', b'a', b'automation', b'braintree', b'shining', b'crumble',
# Nearest to b'an': b'modified', b'warrington', b'atx', b'dassault', b'erudite', b'musket', b'pairing', b'textile',
# Nearest to b'history': b'matra', b'aar', b'ladder', b'maui', b'antiquity', b'dance', b'mithras', b'list',
# Nearest to b'to': b'could', b'consular', b'can', b'unresponsive', b'disqualification', b'gordie', b'in', b'will',
# Nearest to b'may': b'can', b'would', b'will', b'could', b'should', b'must', b'might', b'interprets',
# Nearest to b'for': b'of', b'from', b'in', b'formant', b'appleseed', b'resilient', b'is', b'berman',
# Nearest to b'some': b'many', b'these', b'several', b'any', b'most', b'both', b'those', b'gush',
# Nearest to b'th': b'eight', b'noradrenaline', b'culver', b'fdp', b'six', b'angrily', b'pineapples', b'zero',
# Nearest to b'more': b'less', b'rather', b'very', b'most', b'greater', b'longer', b'parades', b'mobile',
# Nearest to b'eight': b'nine', b'seven', b'six', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'where', b'when', b'though', b'spoiling', b'is', b'correlation', b'franconia', b'distinguishable',
# Average loss at step 42000 : 3.43592549515
# Average loss at step 44000 : 3.45167308205
# Average loss at step 46000 : 3.44748455375
# Average loss at step 48000 : 3.35017773998
# Average loss at step 50000 : 3.382172562
# Nearest to b'a': b'the', b'another', b'any', b'customarily', b'fridays', b'traceable', b'weiner', b'harbin',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'mizrahi', b'soon', b'chechens',
# Nearest to b'about': b'aha', b'around', b'virgins', b'on', b'altimeter', b'ulrich', b'realaudio', b'textbooks',
# Nearest to b'has': b'had', b'have', b'was', b'is', b'plebeians', b'rowan', b'nativity', b'indivisible',
# Nearest to b'was': b'is', b'were', b'became', b'has', b'had', b'been', b'by', b'be',
# Nearest to b'b': b'd', b'ruinous', b'f', b'chlamydia', b'crumble', b'adm', b'dusk', b'c',
# Nearest to b'an': b'warrington', b'vpi', b'modified', b'dassault', b'pairing', b'erudite', b'nonaligned', b'hops',
# Nearest to b'history': b'ladder', b'matra', b'dance', b'aar', b'list', b'maui', b'cerium', b'workgroups',
# Nearest to b'to': b'could', b'consular', b'will', b'discharge', b'may', b'can', b'disqualification', b'tougher',
# Nearest to b'may': b'can', b'would', b'will', b'should', b'could', b'must', b'might', b'cannot',
# Nearest to b'for': b'formant', b'although', b'including', b'popularizing', b'on', b'titular', b'ephraem', b'raccoon',
# Nearest to b'some': b'many', b'these', b'several', b'both', b'most', b'any', b'various', b'trapdoor',
# Nearest to b'th': b'five', b'noradrenaline', b'four', b'culver', b'eight', b'fdp', b'six', b'st',
# Nearest to b'more': b'less', b'most', b'rather', b'very', b'greater', b'highly', b'longer', b'mobile',
# Nearest to b'eight': b'six', b'nine', b'four', b'seven', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'when', b'where', b'though', b'although', b'does', b'asf', b'flocks', b'whether',
# Average loss at step 52000 : 3.4400645619
# Average loss at step 54000 : 3.42322642118
# Average loss at step 56000 : 3.4409994387
# Average loss at step 58000 : 3.3993066051
# Average loss at step 60000 : 3.39128159365
# Nearest to b'a': b'any', b'the', b'fridays', b'customarily', b'every', b'crass', b'another', b'sneaking',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'soon', b'never', b'futile',
# Nearest to b'about': b'aha', b'around', b'over', b'on', b'lavrenty', b'altimeter', b'virgins', b'gottlob',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'having', b'includes', b'plebeians', b'yet',
# Nearest to b'was': b'is', b'had', b'became', b'were', b'has', b'be', b'although', b'becomes',
# Nearest to b'b': b'd', b'c', b'p', b'f', b'automation', b'r', b'm', b'adm',
# Nearest to b'an': b'multinational', b'the', b'warrington', b'erudite', b'pairing', b'millsaps', b'thicknesses', b'vpi',
# Nearest to b'history': b'matra', b'list', b'aar', b'dance', b'sifre', b'philosophy', b'geography', b'workgroups',
# Nearest to b'to': b'consular', b'tougher', b'would', b'discharge', b'unresponsive', b'not', b'beth', b'clerics',
# Nearest to b'may': b'can', b'will', b'would', b'could', b'should', b'must', b'might', b'cannot',
# Nearest to b'for': b'including', b'of', b'without', b'by', b'raccoon', b'lucia', b'unsustainable', b'earliest',
# Nearest to b'some': b'many', b'several', b'these', b'most', b'any', b'this', b'all', b'both',
# Nearest to b'th': b'eight', b'five', b'four', b'fdp', b'st', b'noradrenaline', b'culver', b'one',
# Nearest to b'more': b'less', b'rather', b'greater', b'very', b'most', b'longer', b'highly', b'mobile',
# Nearest to b'eight': b'nine', b'six', b'four', b'seven', b'five', b'three', b'zero', b'two',
# Nearest to b'if': b'when', b'where', b'though', b'then', b'although', b'since', b'does', b'whether',
# Average loss at step 62000 : 3.23964331955
# Average loss at step 64000 : 3.25891579658
# Average loss at step 66000 : 3.40317605293
# Average loss at step 68000 : 3.38599182713
# Average loss at step 70000 : 3.36075211293
# Nearest to b'a': b'customarily', b'the', b'another', b'any', b'fridays', b'crouch', b'guericke', b'harbin',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'soon', b'who', b'futile', b'slurs',
# Nearest to b'about': b'aha', b'around', b'on', b'altimeter', b'lavrenty', b'deserved', b'realaudio', b'accustomed',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'curious', b'includes', b'aung', b'indivisible',
# Nearest to b'was': b'is', b'has', b'were', b'had', b'became', b'been', b'defeating', b'be',
# Nearest to b'b': b'd', b'f', b'r', b'h', b'mathbf', b'j', b'p', b'frac',
# Nearest to b'an': b'dassault', b'atx', b'warrington', b'the', b'antioch', b'pairing', b'coincide', b'musket',
# Nearest to b'history': b'list', b'aar', b'dance', b'matra', b'sifre', b'workgroups', b'maui', b'geography',
# Nearest to b'to': b'will', b'unresponsive', b'consular', b'must', b'would', b'tougher', b'discharge', b'for',
# Nearest to b'may': b'can', b'will', b'would', b'could', b'must', b'should', b'might', b'cannot',
# Nearest to b'for': b'including', b'raccoon', b'resilient', b'formant', b'to', b'belushi', b'denslow', b'titular',
# Nearest to b'some': b'many', b'several', b'these', b'most', b'various', b'trapdoor', b'all', b'any',
# Nearest to b'th': b'fdp', b'culver', b'bc', b'noradrenaline', b'st', b'eight', b'sq', b'six',
# Nearest to b'more': b'less', b'rather', b'most', b'very', b'greater', b'highly', b'longer', b'smaller',
# Nearest to b'eight': b'nine', b'six', b'seven', b'four', b'five', b'zero', b'three', b'two',
# Nearest to b'if': b'when', b'where', b'though', b'since', b'although', b'distinguishable', b'because', b'could',
# Average loss at step 72000 : 3.36861623925
# Average loss at step 74000 : 3.35100831531
# Average loss at step 76000 : 3.3198208428
# Average loss at step 78000 : 3.34977679062
# Average loss at step 80000 : 3.37784292018
# Nearest to b'a': b'another', b'the', b'customarily', b'fridays', b'delirium', b'difranco', b'vald', b'every',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'maxi', b'finale', b'soon',
# Nearest to b'about': b'aha', b'around', b'over', b'altimeter', b'textbooks', b'virgins', b'insular', b'seated',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'although', b'having', b'curious', b'since',
# Nearest to b'was': b'is', b'became', b'were', b'has', b'had', b'been', b'dale', b'becomes',
# Nearest to b'b': b'd', b'c', b'm', b'f', b'r', b'ruinous', b'j', b'p',
# Nearest to b'an': b'dassault', b'londoners', b'antioch', b'warrington', b'blake', b'analogy', b'multinational', b'musket',
# Nearest to b'history': b'matra', b'aar', b'list', b'dance', b'endpoints', b'fertilisation', b'bronze', b'workgroups',
# Nearest to b'to': b'will', b'discharge', b'would', b'disqualification', b'fraenkel', b'must', b'should', b'tougher',
# Nearest to b'may': b'can', b'could', b'will', b'would', b'might', b'must', b'should', b'cannot',
# Nearest to b'for': b'including', b'titular', b'mckinney', b'sausages', b'blanket', b'ultrasonic', b'formant', b'although',
# Nearest to b'some': b'many', b'several', b'these', b'most', b'various', b'any', b'all', b'both',
# Nearest to b'th': b'sq', b'fourth', b'rd', b'culver', b'bc', b'fdp', b'five', b'noradrenaline',
# Nearest to b'more': b'less', b'rather', b'very', b'most', b'greater', b'highly', b'quite', b'longer',
# Nearest to b'eight': b'nine', b'six', b'seven', b'five', b'four', b'three', b'zero', b'two',
# Nearest to b'if': b'when', b'though', b'where', b'since', b'then', b'because', b'although', b'before',
# Average loss at step 82000 : 3.40668195331
# Average loss at step 84000 : 3.40941790128
# Average loss at step 86000 : 3.39116124228
# Average loss at step 88000 : 3.3497970506
# Average loss at step 90000 : 3.36536066908
# Nearest to b'a': b'fridays', b'customarily', b'any', b'another', b'guericke', b'the', b'difranco', b'toc',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'soon', b'we', b'probably',
# Nearest to b'about': b'around', b'aha', b'closes', b'textbooks', b'on', b'insular', b'mi', b'realaudio',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'since', b'having', b'although', b'requires',
# Nearest to b'was': b'is', b'were', b'became', b'had', b'has', b'been', b'being', b'be',
# Nearest to b'b': b'd', b'f', b'c', b'j', b'r', b'tyndall', b'm', b'neutron',
# Nearest to b'an': b'another', b'pairing', b'millsaps', b'lunch', b'warrington', b'bg', b'antioch', b'janissaries',
# Nearest to b'history': b'list', b'aar', b'matra', b'endpoints', b'philosophy', b'dance', b'geography', b'statues',
# Nearest to b'to': b'would', b'disqualification', b'verizon', b'will', b'discharge', b'unresponsive', b'towards', b'through',
# Nearest to b'may': b'can', b'could', b'might', b'will', b'would', b'must', b'should', b'cannot',
# Nearest to b'for': b'including', b'formant', b'blanket', b'belushi', b'mckinney', b'against', b'of', b'after',
# Nearest to b'some': b'many', b'several', b'these', b'most', b'any', b'various', b'those', b'certain',
# Nearest to b'th': b'seven', b'eight', b'one', b'sq', b'rd', b'bc', b'fourth', b'culver',
# Nearest to b'more': b'less', b'very', b'rather', b'most', b'highly', b'greater', b'extremely', b'quite',
# Nearest to b'eight': b'seven', b'six', b'nine', b'five', b'four', b'three', b'zero', b'two',
# Nearest to b'if': b'when', b'where', b'though', b'since', b'whenever', b'regained', b'then', b'is',
# Average loss at step 92000 : 3.39447908568
# Average loss at step 94000 : 3.25608645219
# Average loss at step 96000 : 3.35869018555
# Average loss at step 98000 : 3.24095181984
# Average loss at step 100000 : 3.35610587043
# Nearest to b'a': b'another', b'any', b'the', b'fridays', b'enriched', b'every', b'clearances', b'difranco',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'we', b'there', b'never', b'soon',
# Nearest to b'about': b'around', b'closes', b'aha', b'supplements', b'racehorse', b'bannockburn', b'on', b'downstream',
# Nearest to b'has': b'had', b'have', b'is', b'was', b'having', b'since', b'curious', b'charlton',
# Nearest to b'was': b'is', b'has', b'became', b'were', b'had', b'been', b'being', b'began',
# Nearest to b'b': b'd', b'neutron', b'hadn', b'mindstorms', b'c', b'swedish', b'uncommonly', b'covalently',
# Nearest to b'an': b'warrington', b'another', b'dassault', b'pairing', b'erudite', b'antioch', b'anacharsis', b'urgency',
# Nearest to b'history': b'list', b'matra', b'aar', b'geography', b'endpoints', b'intellectual', b'dance', b'bronze',
# Nearest to b'to': b'consular', b'will', b'and', b'discharge', b'should', b'could', b'would', b'can',
# Nearest to b'may': b'can', b'could', b'might', b'would', b'should', b'must', b'will', b'cannot',
# Nearest to b'for': b'when', b'against', b'without', b'including', b'after', b'blanket', b'denslow', b'prematurely',
# Nearest to b'some': b'many', b'several', b'these', b'any', b'various', b'most', b'those', b'certain',
# Nearest to b'th': b'rd', b'bc', b'sq', b'fourth', b'second', b'culver', b'angrily', b'next',
# Nearest to b'more': b'less', b'most', b'very', b'rather', b'highly', b'greater', b'extremely', b'quite',
# Nearest to b'eight': b'seven', b'nine', b'five', b'six', b'four', b'three', b'zero', b'two',
# Nearest to b'if': b'when', b'where', b'though', b'before', b'since', b'whenever', b'because', b'regained',

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0
def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(int(batch_size / num_skips)):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step", step, ":", average_loss)
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = "Nearest to %s:" % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = "%s %s," % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0 : 8.47136497498
# Nearest to b'four': b'darpa', b'supra', b'indispensable', b'injury', b'adoptive', b'franke', b'juncture', b'hausdorff',
# Nearest to b'were': b'gui', b'casualty', b'etzel', b'pitch', b'amin', b'systema', b'graeme', b'underlies',
# Nearest to b'he': b'andrei', b'disapproved', b'reduced', b'forfeit', b'presentation', b'tahitian', b'firearm', b'apolitical',
# Nearest to b'all': b'cartridge', b'freezes', b'infrastructural', b'denaturation', b'eixample', b'mysterious', b'rewarding', b'gamete',
# Nearest to b'at': b'variations', b'billions', b'limestone', b'usurp', b'hard', b'uptake', b'diacritics', b'coiled',
# Nearest to b'some': b'macs', b'hides', b'erudite', b'welterweight', b'fucked', b'estate', b'foreigner', b'nw',
# Nearest to b'b': b'mineral', b'blocked', b'titicaca', b'munich', b'erinyes', b'rias', b'wlad', b'bonanza',
# Nearest to b'new': b'internalism', b'wavering', b'andamanese', b'tabor', b'sylheti', b'pitts', b'stabilized', b'dahl',
# Nearest to b'd': b'maclean', b'perilous', b'typing', b'yetzer', b'sera', b'ornamental', b'agreed', b'tangerine',
# Nearest to b'be': b'jarrett', b'steamers', b'vai', b'gaudy', b'gabriel', b'unfccc', b'microchip', b'fawcett',
# Nearest to b'eight': b'lempel', b'riffing', b'semitone', b'compiler', b'lorry', b'postseason', b'graphemes', b'anions',
# Nearest to b'it': b'jonson', b'stops', b'epithets', b'biases', b'basenjis', b'bnls', b'dyck', b'interpretation',
# Nearest to UNK: b'spreading', b'mating', b'orbiting', b'graphemes', b'fets', b'immanuel', b'sobriety', b'agrippina',
# Nearest to b'these': b'abolish', b'significand', b'refreshing', b'biologist', b'perth', b'depending', b'renouf', b'aut',
# Nearest to b'on': b'notoriety', b'basset', b'friendly', b'autism', b'trophy', b'hiroshima', b'runaway', b'quinine',
# Nearest to b'united': b'subclass', b'habitation', b'algebra', b'spend', b'wholeheartedly', b'jehoiakim', b'azt', b'pleated',
# Average loss at step 2000 : 4.35236606586
# Average loss at step 4000 : 3.8631179831
# Average loss at step 6000 : 3.79137934148
# Average loss at step 8000 : 3.68657262027
# Average loss at step 10000 : 3.62015583682
# Nearest to b'four': b'eight', b'six', b'seven', b'five', b'three', b'two', b'zero', b'nine',
# Nearest to b'were': b'are', b'was', b'have', b'is', b'pitch', b'had', b'skies', b'tomino',
# Nearest to b'he': b'it', b'they', b'she', b'there', b'who', b'forfeit', b'keen', b'gertrude',
# Nearest to b'all': b'some', b'these', b'slurs', b'out', b'unpopularity', b'wit', b'cartridge', b'tambo',
# Nearest to b'at': b'in', b'on', b'during', b'khan', b'by', b'for', b'caucasoid', b'from',
# Nearest to b'some': b'many', b'all', b'these', b'foreman', b'nw', b'macs', b'erudite', b'cemeteries',
# Nearest to b'b': b'd', b'mineral', b'blocked', b'titicaca', b'nhra', b'complexion', b'lomborg', b'rias',
# Nearest to b'new': b'andamanese', b'tabor', b'internalism', b'hailstones', b'whaling', b'cmt', b'materialist', b'crested',
# Nearest to b'd': b'b', b'famagusta', b'maclean', b'situation', b'yetzer', b'typing', b'ornamental', b'urbanization',
# Nearest to b'be': b'have', b'jarrett', b'was', b'is', b'by', b'schiavo', b'strikeouts', b'were',
# Nearest to b'eight': b'six', b'nine', b'four', b'five', b'seven', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'there', b'this', b'which', b'that', b'not', b'no', b'they',
# Nearest to UNK: b'mazarin', b'ohio', b'reformed', b'ministry', b'abb', b'toolkit', b'schemes', b'conservatory',
# Nearest to b'these': b'some', b'many', b'saterland', b'depending', b'municipalities', b'oklahoma', b'biologist', b'all',
# Nearest to b'on': b'in', b'at', b'of', b'yielding', b'guards', b'colorful', b'sow', b'descriptive',
# Nearest to b'united': b'pleated', b'loneliness', b'eiji', b'rat', b'habitation', b'tissues', b'algebra', b'vulnerabilities',
# Average loss at step 12000 : 3.60127888948
# Average loss at step 14000 : 3.57177949411
# Average loss at step 16000 : 3.41347420388
# Average loss at step 18000 : 3.45923148489
# Average loss at step 20000 : 3.53783426023
# Nearest to b'four': b'eight', b'seven', b'three', b'five', b'six', b'two', b'nine', b'one',
# Nearest to b'were': b'are', b'was', b'had', b'have', b'be', b'being', b'tupac', b'is',
# Nearest to b'he': b'it', b'she', b'they', b'who', b'there', b'ayres', b'which', b'matte',
# Nearest to b'all': b'some', b'many', b'these', b'several', b'out', b'ignatius', b'tambo', b'cartridge',
# Nearest to b'at': b'in', b'during', b'on', b'above', b'like', b'from', b'and', b'with',
# Nearest to b'some': b'many', b'these', b'several', b'all', b'foreman', b'cemeteries', b'erudite', b'the',
# Nearest to b'b': b'd', b'literary', b'uplifting', b'blocked', b'cabbie', b'stitches', b'actor', b'silesian',
# Nearest to b'new': b'tabor', b'hailstones', b'andamanese', b'popular', b'carabiners', b'pleaded', b'internalism', b'goalkeeper',
# Nearest to b'd': b'b', b'cabbie', b'famagusta', b'compromising', b'hoffa', b'liberians', b'econometrics', b'urbanization',
# Nearest to b'be': b'have', b'was', b'been', b'wreath', b'were', b'by', b'jarrett', b'strikeouts',
# Nearest to b'eight': b'six', b'seven', b'nine', b'four', b'five', b'three', b'two', b'zero',
# Nearest to b'it': b'he', b'this', b'there', b'they', b'which', b'also', b'not', b'iambic',
# Nearest to UNK: b'tucker', b'seismology', b'i', b'ministry', b'sempronius', b'aileen', b'investigator', b'alves',
# Nearest to b'these': b'some', b'many', b'all', b'several', b'other', b'which', b'such', b'bed',
# Nearest to b'on': b'in', b'at', b'upon', b'during', b'descriptive', b'shen', b'brooklynites', b'whiz',
# Nearest to b'united': b'pleated', b'loneliness', b'rat', b'tissues', b'eiji', b'nba', b'joule', b'vulnerabilities',
# Average loss at step 22000 : 3.50553532043
# Average loss at step 24000 : 3.49031531447
# Average loss at step 26000 : 3.48409116006
# Average loss at step 28000 : 3.48077219939
# Average loss at step 30000 : 3.50088658929
# Nearest to b'four': b'five', b'six', b'three', b'eight', b'seven', b'two', b'nine', b'zero',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'been', b'tupac', b'tyne', b'fir',
# Nearest to b'he': b'it', b'she', b'they', b'there', b'who', b'matte', b'schleicher', b'ayres',
# Nearest to b'all': b'these', b'some', b'many', b'out', b'allegation', b'several', b'those', b'members',
# Nearest to b'at': b'during', b'in', b'on', b'erase', b'moist', b'conjectural', b'lublin', b'after',
# Nearest to b'some': b'many', b'these', b'several', b'all', b'the', b'most', b'cemeteries', b'both',
# Nearest to b'b': b'd', b'literary', b'blocked', b'sapkowski', b'saimei', b'cabbie', b'photorealistic', b'geoid',
# Nearest to b'new': b'tabor', b'andamanese', b'hailstones', b'protectionism', b'basic', b'carabiners', b'macintosh', b'embarrassed',
# Nearest to b'd': b'b', b'cabbie', b'ash', b'recherche', b'puzo', b'liberians', b'hoffa', b'wta',
# Nearest to b'be': b'have', b'been', b'restraints', b'jarrett', b'kino', b'refer', b'wreath', b'is',
# Nearest to b'eight': b'nine', b'six', b'seven', b'five', b'four', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'this', b'there', b'she', b'they', b'mcguire', b'bosniak', b'which',
# Nearest to UNK: b'rudd', b'extradition', b'eisa', b'shamanic', b'multiples', b'alves', b'cartesian', b'appreciative',
# Nearest to b'these': b'some', b'many', b'all', b'several', b'such', b'both', b'they', b'various',
# Nearest to b'on': b'upon', b'at', b'in', b'for', b'descriptive', b'nap', b'through', b'from',
# Nearest to b'united': b'pleated', b'joule', b'european', b'omitting', b'vulnerabilities', b'rat', b'habitation', b'usaf',
# Average loss at step 32000 : 3.49997520918
# Average loss at step 34000 : 3.49395742548
# Average loss at step 36000 : 3.45035353327
# Average loss at step 38000 : 3.29951021177
# Average loss at step 40000 : 3.43216888046
# Nearest to b'four': b'six', b'seven', b'five', b'eight', b'three', b'two', b'nine', b'one',
# Nearest to b'were': b'are', b'have', b'was', b'being', b'been', b'had', b'be', b'fir',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'there', b'i', b'we', b'ayres',
# Nearest to b'all': b'these', b'both', b'offshore', b'many', b'several', b'dillinger', b'wit', b'sphere',
# Nearest to b'at': b'during', b'on', b'in', b'enclosure', b'billions', b'khan', b'lublin', b'caucasoid',
# Nearest to b'some': b'many', b'these', b'several', b'both', b'various', b'those', b'any', b'foreman',
# Nearest to b'b': b'd', b'digamma', b'births', b'cabbie', b'stitches', b'codec', b'sapkowski', b'pears',
# Nearest to b'new': b'tabor', b'andamanese', b'covenants', b'modern', b'basic', b'grounded', b'carabiners', b'macintosh',
# Nearest to b'd': b'b', b'c', b'roger', b'robert', b'te', UNK, b'recherche', b'wta',
# Nearest to b'be': b'been', b'have', b'refer', b'restraints', b'try', b'were', b'is', b'are',
# Nearest to b'eight': b'nine', b'seven', b'six', b'four', b'five', b'three', b'zero', b'one',
# Nearest to b'it': b'he', b'there', b'she', b'they', b'this', b'which', b'what', b'we',
# Nearest to UNK: b'bloated', b'shulkhan', b'schemes', b'd', b'extradition', b'and', b'miscible', b'aquifer',
# Nearest to b'these': b'some', b'many', b'several', b'various', b'such', b'both', b'all', b'they',
# Nearest to b'on': b'upon', b'at', b'yielding', b'in', b'schuster', b'from', b'around', b'between',
# Nearest to b'united': b'joule', b'pleated', b'vulnerabilities', b'european', b'omitting', b'lifespans', b'esdi', b'tissues',
# Average loss at step 42000 : 3.43518958843
# Average loss at step 44000 : 3.45174467885
# Average loss at step 46000 : 3.44901674056
# Average loss at step 48000 : 3.35446383005
# Average loss at step 50000 : 3.3817184307
# Nearest to b'four': b'six', b'seven', b'eight', b'three', b'five', b'nine', b'two', b'zero',
# Nearest to b'were': b'are', b'was', b'have', b'be', b'had', b'being', b'been', b'fir',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'there', b'we', b'soon', b'never',
# Nearest to b'all': b'both', b'perception', b'these', b'each', b'many', b'offshore', b'dillinger', b'some',
# Nearest to b'at': b'during', b'near', b'on', b'beauvoir', b'in', b'daniels', b'caucasoid', b'erase',
# Nearest to b'some': b'many', b'these', b'several', b'both', b'various', b'those', b'the', b'suiko',
# Nearest to b'b': b'd', b'births', b'codec', b'weiser', b'duma', b'stitches', b'pulverized', b'tyrannical',
# Nearest to b'new': b'tabor', b'funneled', b'basic', b'embarrassed', b'carabiners', b'macintosh', b'multi', b'olin',
# Nearest to b'd': b'b', b'roger', b'robert', b'distributors', b'montmartre', b'te', b'l', b'f',
# Nearest to b'be': b'was', b'have', b'been', b'were', b'being', b'is', b'become', b'refer',
# Nearest to b'eight': b'six', b'seven', b'nine', b'four', b'three', b'five', b'two', b'zero',
# Nearest to b'it': b'he', b'there', b'she', b'this', b'they', b'iambic', b'which', b'galahad',
# Nearest to UNK: b'dredging', b'bastille', b'registering', b'de', b'ecoregions', b'historian', b'acyclic', b'et',
# Nearest to b'these': b'some', b'many', b'several', b'various', b'both', b'such', b'those', b'certain',
# Nearest to b'on': b'upon', b'through', b'from', b'in', b'descriptive', b'yielding', b'around', b'over',
# Nearest to b'united': b'joule', b'vulnerabilities', b'pleated', b'omitting', b'same', b'esdi', b'european', b'spend',
# Average loss at step 52000 : 3.43837332106
# Average loss at step 54000 : 3.42375536948
# Average loss at step 56000 : 3.43972898412
# Average loss at step 58000 : 3.39853988194
# Average loss at step 60000 : 3.39625352591
# Nearest to b'four': b'six', b'eight', b'five', b'seven', b'three', b'nine', b'two', b'zero',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'including', b'while', b'those', b'tupac',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'we', b'never', b'finally',
# Nearest to b'all': b'both', b'many', b'some', b'any', b'these', b'most', b'those', b'several',
# Nearest to b'at': b'during', b'in', b'near', b'under', b'enclosure', b'lublin', b'dissolves', b'on',
# Nearest to b'some': b'many', b'several', b'these', b'all', b'most', b'any', b'various', b'this',
# Nearest to b'b': b'd', b'births', b'duma', b'm', b'codec', b'n', b'r', b'c',
# Nearest to b'new': b'tabor', b'macintosh', b'covenants', b'recent', b'modern', b'basic', b'funneled', b'fen',
# Nearest to b'd': b'b', b'te', b'robert', b'roger', b'recherche', b'c', b'l', b'econometrics',
# Nearest to b'be': b'been', b'try', b'was', b'are', b'have', b'become', b'achieve', b'is',
# Nearest to b'eight': b'nine', b'six', b'four', b'seven', b'five', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'she', b'there', b'this', b'what', b'that', b'hermeneutics', b'then',
# Nearest to UNK: b'rituals', b'stuart', b'zhaozhou', b'amid', b'sines', b'occult', b'shankar', b'acyclic',
# Nearest to b'these': b'some', b'many', b'both', b'several', b'those', b'such', b'certain', b'different',
# Nearest to b'on': b'upon', b'through', b'descriptive', b'yielding', b'in', b'under', b'colorful', b'about',
# Nearest to b'united': b'joule', b'pleated', b'vulnerabilities', b'omitting', b'european', b'usaf', b'tissues', b'same',
# Average loss at step 62000 : 3.23324705058
# Average loss at step 64000 : 3.25234642893
# Average loss at step 66000 : 3.39999287719
# Average loss at step 68000 : 3.39487732142
# Average loss at step 70000 : 3.36133472413
# Nearest to b'four': b'five', b'six', b'seven', b'three', b'eight', b'zero', b'two', b'nine',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'been', b'be', b'including', b'tupac',
# Nearest to b'he': b'she', b'it', b'they', b'who', b'we', b'there', b'never', b'soon',
# Nearest to b'all': b'many', b'some', b'both', b'various', b'any', b'every', b'most', b'several',
# Nearest to b'at': b'during', b'near', b'in', b'under', b'enclosure', b'after', b'before', b'moist',
# Nearest to b'some': b'many', b'several', b'most', b'these', b'all', b'various', b'those', b'certain',
# Nearest to b'b': b'd', b'r', b'duma', b'te', b'births', b'medalists', b'pulverized', b'f',
# Nearest to b'new': b'strong', b'macintosh', b'multi', b'fen', b'academic', b'modern', b'recent', b'covenants',
# Nearest to b'd': b'b', b'te', b'roger', b'robert', b'o', b'econometrics', b'recherche', b'l',
# Nearest to b'be': b'been', b'is', b'have', b'become', b'were', b'being', b'refer', b'restraints',
# Nearest to b'eight': b'six', b'nine', b'seven', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'she', b'there', b'this', b'they', b'we', b'still', b'departing',
# Nearest to UNK: b'analytical', b'harmonising', b'orville', b'telescopic', b'reveal', b'rev', b'lsi', b'cauldron',
# Nearest to b'these': b'such', b'many', b'some', b'several', b'various', b'are', b'the', b'which',
# Nearest to b'on': b'upon', b'through', b'in', b'descriptive', b'within', b'about', b'antonius', b'yielding',
# Nearest to b'united': b'joule', b'same', b'omitting', b'pleated', b'european', b'usaf', b'vulnerabilities', b'tissues',
# Average loss at step 72000 : 3.37766946232
# Average loss at step 74000 : 3.35097459037
# Average loss at step 76000 : 3.31384539378
# Average loss at step 78000 : 3.35304413491
# Average loss at step 80000 : 3.37584627753
# Nearest to b'four': b'five', b'six', b'three', b'seven', b'eight', b'two', b'nine', b'zero',
# Nearest to b'were': b'are', b'was', b'had', b'have', b'been', b'those', b'became', b'tupac',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'we', b'never', b'soon',
# Nearest to b'all': b'both', b'many', b'various', b'every', b'any', b'some', b'those', b'unpopularity',
# Nearest to b'at': b'in', b'during', b'around', b'on', b'enclosure', b'mujahedeen', b'after', b'judit',
# Nearest to b'some': b'many', b'several', b'these', b'most', b'various', b'numerous', b'certain', b'both',
# Nearest to b'b': b'd', b'births', b'duma', b'm', b'medalists', b'te', b'frankenheimer', b'r',
# Nearest to b'new': b'modern', b'macintosh', b'old', b'recent', b'stealth', b'multi', b'massive', b'fen',
# Nearest to b'd': b'b', b'te', b'roger', b'l', b'o', b'commentarii', b'upstairs', b'f',
# Nearest to b'be': b'been', b'become', b'being', b'try', b'have', b'refer', b'elaborates', b'achieve',
# Nearest to b'eight': b'nine', b'seven', b'six', b'five', b'four', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'she', b'there', b'this', b'they', b'mcguire', b'we', b'nothing',
# Nearest to UNK: b'mazarin', b'lombard', b'coach', b'searle', b'heiden', b'aileen', b'alligators', b'fundamento',
# Nearest to b'these': b'several', b'many', b'some', b'various', b'both', b'those', b'such', b'which',
# Nearest to b'on': b'upon', b'in', b'through', b'yielding', b'at', b'and', b'sagrada', b'antonius',
# Nearest to b'united': b'joule', b'same', b'usaf', b'pleated', b'european', b'drove', b'omitting', b'gregorian',
# Average loss at step 82000 : 3.40593996572
# Average loss at step 84000 : 3.40738701999
# Average loss at step 86000 : 3.38862571305
# Average loss at step 88000 : 3.35031985831
# Average loss at step 90000 : 3.36704314065
# Nearest to b'four': b'seven', b'five', b'six', b'eight', b'three', b'two', b'nine', b'zero',
# Nearest to b'were': b'are', b'had', b'was', b'have', b'those', b'while', b'been', b'tupac',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'finally', b'but', b'soon',
# Nearest to b'all': b'both', b'some', b'many', b'various', b'several', b'any', b'those', b'these',
# Nearest to b'at': b'during', b'on', b'near', b'moist', b'in', b'under', b'coached', b'circumflex',
# Nearest to b'some': b'many', b'several', b'any', b'these', b'all', b'most', b'certain', b'both',
# Nearest to b'b': b'd', b'births', b'duma', b'n', b'te', b'm', b'frankenheimer', b'r',
# Nearest to b'new': b'modern', b'old', b'rota', b'macintosh', b'pure', b'recent', b'funneled', b'academic',
# Nearest to b'd': b'b', b'commentarii', b'pp', b'upstairs', b'l', b'brindisi', b'te', b'f',
# Nearest to b'be': b'been', b'become', b'was', b'have', b'being', b'try', b'is', b'are',
# Nearest to b'eight': b'seven', b'nine', b'six', b'four', b'five', b'three', b'zero', b'two',
# Nearest to b'it': b'he', b'she', b'there', b'this', b'they', b'which', b'itself', b'trichechus',
# Nearest to UNK: b'fusiliers', b'alligators', b'unsaturated', b'carp', b'chechens', b'rev', b'et', b'extrinsic',
# Nearest to b'these': b'many', b'several', b'some', b'various', b'those', b'such', b'both', b'are',
# Nearest to b'on': b'upon', b'under', b'through', b'at', b'around', b'in', b'nap', b'yielding',
# Nearest to b'united': b'joule', b'same', b'usaf', b'gregorian', b'omitting', b'drove', b'lifespans', b'crassus',
# Average loss at step 92000 : 3.39287688696
# Average loss at step 94000 : 3.25171866381
# Average loss at step 96000 : 3.35925087643
# Average loss at step 98000 : 3.24342791992
# Average loss at step 100000 : 3.35416416085
# Nearest to b'four': b'seven', b'six', b'five', b'eight', b'three', b'two', b'nine', b'zero',
# Nearest to b'were': b'are', b'was', b'had', b'have', b'although', b'those', b'these', b'eleonora',
# Nearest to b'he': b'she', b'it', b'they', b'there', b'who', b'we', b'soon', b'never',
# Nearest to b'all': b'several', b'many', b'various', b'both', b'some', b'these', b'any', b'those',
# Nearest to b'at': b'during', b'in', b'near', b'on', b'after', b'introduces', b'until', b'under',
# Nearest to b'some': b'many', b'several', b'these', b'certain', b'any', b'all', b'various', b'those',
# Nearest to b'b': b'd', b'photorealistic', b'murbella', b'zephaniah', b'codec', b'te', b'crescent', b'jordanian',
# Nearest to b'new': b'modern', b'macintosh', b'old', b'different', b'stealth', b'abugida', b'recent', b'academic',
# Nearest to b'd': b'b', b'cabbie', b'te', b'decimal', b'distributors', b'pellucidar', b'c', b'gustav',
# Nearest to b'be': b'been', b'refer', b'have', b'become', b'being', b'try', b'is', b'easily',
# Nearest to b'eight': b'nine', b'seven', b'six', b'four', b'five', b'zero', b'three', b'two',
# Nearest to b'it': b'he', b'she', b'this', b'there', b'they', b'nothing', b'trichechus', b'departing',
# Nearest to UNK: b'foes', b'von', b'rinzai', b'ist', b'eisa', b'precede', b'telescopic', b'sullivan',
# Nearest to b'these': b'several', b'some', b'many', b'various', b'those', b'all', b'both', b'different',
# Nearest to b'on': b'upon', b'through', b'in', b'under', b'at', b'within', b'around', b'adopters',
# Nearest to b'united': b'joule', b'gregorian', b'usaf', b'same', b'omitting', b'european', b'nation', b'esdi',

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
