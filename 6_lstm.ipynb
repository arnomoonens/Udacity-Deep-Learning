# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.298190 learning rate: 10.000000
# Minibatch perplexity: 27.06
# ================================================================================
# fspflatjy ywnhtupkkje snvlttgadonbatne bqbir nb lendwacrgjmwtmlgrdtdknx   niihrs
# nobjbjclbhkesrshigzyk  jswn aonclerptiico ba jhjttcoobaedsdpoeereetetntgajdoiswu
# ufkptiexn i m   pakjhlfttoozfearhjn    bf upimoaxrrtb lrzxbsuhqodhqbbeaepcgwls g
# hj i  o hshmlwx zcooo ianoolslh htnsgke rya eo hdsrtv ooap ezlm jzg dkfdxaata hf
# rxnnrmmsuagcdj vksttm dka gexfmijqne f hrmwesx etie gikeo uvtatyof jsaondaycfney
# ================================================================================
# Validation set perplexity: 20.34
# Average loss at step 100: 2.590195 learning rate: 10.000000
# Minibatch perplexity: 10.88
# Validation set perplexity: 10.31
# Average loss at step 200: 2.247520 learning rate: 10.000000
# Minibatch perplexity: 8.66
# Validation set perplexity: 8.56
# Average loss at step 300: 2.101605 learning rate: 10.000000
# Minibatch perplexity: 7.43
# Validation set perplexity: 7.94
# Average loss at step 400: 2.001326 learning rate: 10.000000
# Minibatch perplexity: 7.68
# Validation set perplexity: 7.62
# Average loss at step 500: 1.934350 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 7.11
# Average loss at step 600: 1.907660 learning rate: 10.000000
# Minibatch perplexity: 6.13
# Validation set perplexity: 6.91
# Average loss at step 700: 1.861457 learning rate: 10.000000
# Minibatch perplexity: 6.52
# Validation set perplexity: 6.48
# Average loss at step 800: 1.819988 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 6.34
# Average loss at step 900: 1.827954 learning rate: 10.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 6.28
# Average loss at step 1000: 1.830521 learning rate: 10.000000
# Minibatch perplexity: 5.71
# ================================================================================
# n of ofary unfolledy frequmation of exart dest duch consefiel whicl wecenk of sa
# varces which the usignoal an the learinas deage whee sactory it lowt usign resin
# wased which have the dised and on tement cictarion adail satle bnisaits recesson
# chem befosed the copver debserect partor and is the enote mode istency in a prov
# gechill fan applefkants to learty from two falso from wetequz but diise of an re
# ================================================================================
# Validation set perplexity: 6.09
# Average loss at step 1100: 1.777498 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.90
# Average loss at step 1200: 1.753355 learning rate: 10.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 5.61
# Average loss at step 1300: 1.733303 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 5.62
# Average loss at step 1400: 1.751865 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 5.54
# Average loss at step 1500: 1.735492 learning rate: 10.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 5.45
# Average loss at step 1600: 1.748986 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.44
# Average loss at step 1700: 1.715475 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 5.34
# Average loss at step 1800: 1.675262 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.25
# Average loss at step 1900: 1.648395 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.20
# Average loss at step 2000: 1.695223 learning rate: 10.000000
# Minibatch perplexity: 5.67
# ================================================================================
# ga few three years lide for lalism isteved in a decuss the nah bove the decidely
# vain of proke in w becemeral idicy of the cape a hamines l nide preverssing autb
# iky gansumed usly one tic kingodus was we plajk expsition and oftam dialentation
# f film in and gingory of cantit in liger in some list from thus exentina to lead
# lowif wniticianity for recax form allukation ostendants india was incount the mu
# ================================================================================
# Validation set perplexity: 5.24
# Average loss at step 2100: 1.685688 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 5.03
# Average loss at step 2200: 1.684533 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 5.02
# Average loss at step 2300: 1.644001 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.87
# Average loss at step 2400: 1.661393 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.86
# Average loss at step 2500: 1.681890 learning rate: 10.000000
# Minibatch perplexity: 5.43
# Validation set perplexity: 4.79
# Average loss at step 2600: 1.656430 learning rate: 10.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 4.78
# Average loss at step 2700: 1.658523 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.79
# Average loss at step 2800: 1.649818 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.67
# Average loss at step 2900: 1.650976 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 4.90
# Average loss at step 3000: 1.650073 learning rate: 10.000000
# Minibatch perplexity: 5.22
# ================================================================================
# y palshounce a faltical is sone haves auri ans were hole thetbeciple invation is
# fills b in some nation wothers is the fritate is accuired protowicalative firstu
# offfice haby tamand in ismpaces and directed an is landsless a wry tiblt tis air
# was of information refemest outs s is or eir heated about as scyt hargad howdoph
# ancese all wekest force with open s bowe and collean insid the with earady natom
# ================================================================================
# Validation set perplexity: 4.78
# Average loss at step 3100: 1.626569 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 4.69
# Average loss at step 3200: 1.644353 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.69
# Average loss at step 3300: 1.636185 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.59
# Average loss at step 3400: 1.665308 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.68
# Average loss at step 3500: 1.659294 learning rate: 10.000000
# Minibatch perplexity: 5.49
# Validation set perplexity: 4.82
# Average loss at step 3600: 1.672442 learning rate: 10.000000
# Minibatch perplexity: 4.32
# Validation set perplexity: 4.60
# Average loss at step 3700: 1.649788 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.64
# Average loss at step 3800: 1.643323 learning rate: 10.000000
# Minibatch perplexity: 5.67
# Validation set perplexity: 4.73
# Average loss at step 3900: 1.637901 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.63
# Average loss at step 4000: 1.650363 learning rate: 10.000000
# Minibatch perplexity: 4.75
# ================================================================================
# beri its civily repentle chlreming to tkreen delawin restitutions albomarment ye
# x one three two zero zero onetno one nine nine one seven of gass of the s plaiks
# s his papines burte occes a from exterdaber was acamerist relates was bow the ne
# ates irted by mana of a sheaten of nemons a date the clisass americans belaw sut
# orivision with life cases of language inclidentratione howern remonor writel at
# ================================================================================
# Validation set perplexity: 4.60
# Average loss at step 4100: 1.633388 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.75
# Average loss at step 4200: 1.637059 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.56
# Average loss at step 4300: 1.614829 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.57
# Average loss at step 4400: 1.608424 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.45
# Average loss at step 4500: 1.613775 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.60
# Average loss at step 4600: 1.612723 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.69
# Average loss at step 4700: 1.622341 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.64
# Average loss at step 4800: 1.629866 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.58
# Average loss at step 4900: 1.633317 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.66
# Average loss at step 5000: 1.605075 learning rate: 1.000000
# Minibatch perplexity: 4.45
# ================================================================================
# ly fitterns as trout two zero zero zero jeing to the monebra del varvial must ma
# b thi less and consifics was traigns of itsos for quije grade deferencien by not
# lagi lact so eventaly by long a c regus the greegral stimino and to the is east
# ergenon official id the natued harks and iraciey by greated tull the probasentiv
# k to ceros trassivis of a has one nine one zero curred hadnaknor sen langy chara
# ================================================================================
# Validation set perplexity: 4.66
# Average loss at step 5100: 1.605957 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.50
# Average loss at step 5200: 1.590247 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.46
# Average loss at step 5300: 1.577280 learning rate: 1.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 4.42
# Average loss at step 5400: 1.575276 learning rate: 1.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.44
# Average loss at step 5500: 1.566881 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.42
# Average loss at step 5600: 1.576918 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.42
# Average loss at step 5700: 1.565466 learning rate: 1.000000
# Minibatch perplexity: 4.43
# Validation set perplexity: 4.44
# Average loss at step 5800: 1.577690 learning rate: 1.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.45
# Average loss at step 5900: 1.572284 learning rate: 1.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.44
# Average loss at step 6000: 1.542809 learning rate: 1.000000
# Minibatch perplexity: 4.89
# ================================================================================
# ficully ided to airpropraiged british deaked onvingar s re american supposing in
# vely to name cortistint in the reign mitit jolk one fisa will a benericn in thec
# pecture for zized albarnheric this themstheric guochy firating oot over performu
# bal one nine eight seven zero oquent war rights the countrie us topes futioratio
# chus won a prophectriate totating howerb of that the otser differing galnips to
# ================================================================================
# Validation set perplexity: 4.42
# Average loss at step 6100: 1.564418 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.39
# Average loss at step 6200: 1.531231 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.38
# Average loss at step 6300: 1.543530 learning rate: 1.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 4.35
# Average loss at step 6400: 1.540703 learning rate: 1.000000
# Minibatch perplexity: 4.59
# Validation set perplexity: 4.36
# Average loss at step 6500: 1.552779 learning rate: 1.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.35
# Average loss at step 6600: 1.595126 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.37
# Average loss at step 6700: 1.579094 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.35
# Average loss at step 6800: 1.603314 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.33
# Average loss at step 6900: 1.580187 learning rate: 1.000000
# Minibatch perplexity: 4.52
# Validation set perplexity: 4.37
# Average loss at step 7000: 1.573607 learning rate: 1.000000
# Minibatch perplexity: 4.96
# ================================================================================
# y and to the to own bolivian groolag furlly down proposed stardes many spenery o
# ding deftucigh misit issubtive and subrcht the shervorm been there most with acu
# quems amore woldu procparity initial garder rafaviers access of the parturically
# native do visedents effects tewmate trepandsion chick crossely to century online
# n also informanity near b oseutuse while say signation that decessar tymel kilem
# ================================================================================
# Validation set perplexity: 4.37

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  #ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  #fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  #cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  #ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)

  #Instead of ix, fx, cx, ox
  mul_input = tf.Variable(tf.truncated_normal([vocabulary_size, 4*num_nodes], -0.1, 0.1))
  #Instead of im, fm, cm, om
  mul_output = tf.Variable(tf.truncated_normal([num_nodes, 4*num_nodes], -0.1, 0.1))

  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_result = tf.matmul(i, mul_input)
    output_result = tf.matmul(o, mul_output)
    ixr, fxr, cxr, oxr = tf.split(1, 4, input_result)
    imr, fmr, cmr, omr = tf.split(1, 4, output_result)
    input_gate = tf.sigmoid(ixr + imr + ib)
    forget_gate = tf.sigmoid(fxr + fmr + fb)
    update = cxr + cmr + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(oxr + omr + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.294238 learning rate: 10.000000
# Minibatch perplexity: 26.96
# ================================================================================
# biw roveljwektey vrefpeheevjyugje j tcsiwiceqpva dwhhp jx mqxityvgi y mjmb ac je
# tfticegrwl ev jpayc  xcnty ovobdjna n  xoiuxutjyye  tapdt rx mnahoailopniymv knv
# xbpkr nb qrc rn icdiqe r ihan h   blxconskuhven aaiebeko mcazeyjt  ahh srn dfn g
# jihiulkrjuoenibcpontdyxwokvfi ohhfr rdlteosle ahweu xi exs u vcy uoi d  iytxwd a
# ttcjcs uholb bmmv bdftaah ob tllramcv ouemo uodumjpu  cfmenlq rwsagqefqpanidnizg
# ================================================================================
# Validation set perplexity: 20.21
# Average loss at step 100: 2.581096 learning rate: 10.000000
# Minibatch perplexity: 10.89
# Validation set perplexity: 11.06
# Average loss at step 200: 2.255320 learning rate: 10.000000
# Minibatch perplexity: 8.61
# Validation set perplexity: 9.04
# Average loss at step 300: 2.106772 learning rate: 10.000000
# Minibatch perplexity: 7.86
# Validation set perplexity: 8.36
# Average loss at step 400: 2.051189 learning rate: 10.000000
# Minibatch perplexity: 7.40
# Validation set perplexity: 7.65
# Average loss at step 500: 1.999397 learning rate: 10.000000
# Minibatch perplexity: 7.35
# Validation set perplexity: 7.18
# Average loss at step 600: 1.943262 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 7.06
# Average loss at step 700: 1.896206 learning rate: 10.000000
# Minibatch perplexity: 6.82
# Validation set perplexity: 6.76
# Average loss at step 800: 1.876550 learning rate: 10.000000
# Minibatch perplexity: 7.23
# Validation set perplexity: 6.69
# Average loss at step 900: 1.808880 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 6.51
# Average loss at step 1000: 1.815589 learning rate: 10.000000
# Minibatch perplexity: 6.56
# ================================================================================
# g outs fwo nine one nine nine nine seven thrie villawira withs one nine nine fiv
# chifuer this hagdeal croctited of eleded defor kiara celedicly one thrre nine tw
# pentle chinste and two rony conack the prayore that machers al that n allieagy n
# nos orasisn other stalled fia spilv by wneight to one nine nine to agabory booho
# ral vank milaux the of his hissing was and an preat he watbore pholoow of the en
# ================================================================================
# Validation set perplexity: 6.23
# Average loss at step 1100: 1.774295 learning rate: 10.000000
# Minibatch perplexity: 5.54
# Validation set perplexity: 6.01
# Average loss at step 1200: 1.782191 learning rate: 10.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 6.01
# Average loss at step 1300: 1.788684 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.72
# Average loss at step 1400: 1.759099 learning rate: 10.000000
# Minibatch perplexity: 5.86
# Validation set perplexity: 5.55
# Average loss at step 1500: 1.742927 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 5.60
# Average loss at step 1600: 1.731266 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.44
# Average loss at step 1700: 1.720705 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 5.36
# Average loss at step 1800: 1.724609 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.36
# Average loss at step 1900: 1.720851 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.42
# Average loss at step 2000: 1.697665 learning rate: 10.000000
# Minibatch perplexity: 5.04
# ================================================================================
# d doharly the criinations on adrepate of been commen prodibitian fell wither a s
# ned are arinaure afrate devinizations of these the press to are come frolite of
# an diycction as argaza if whree plaw duncanje preuce deist be a promove by never
# ont of met bwonlon steats champore prefement saicter goum fistant coelk he in li
# y prodofers one city conspieuration and brigking sculanic one seven one nine zer
# ================================================================================
# Validation set perplexity: 5.30
# Average loss at step 2100: 1.677054 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.17
# Average loss at step 2200: 1.704028 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 5.17
# Average loss at step 2300: 1.683515 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.22
# Average loss at step 2400: 1.675917 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 5.12
# Average loss at step 2500: 1.666943 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 5.00
# Average loss at step 2600: 1.649415 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.87
# Average loss at step 2700: 1.650236 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.86
# Average loss at step 2800: 1.667625 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.88
# Average loss at step 2900: 1.664098 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 4.67
# Average loss at step 3000: 1.663335 learning rate: 10.000000
# Minibatch perplexity: 5.02
# ================================================================================
# playegus recoveralized white senuent batter to tanallange iarodism smany red maa
# twiale and the tepures such which the senition created ghire not the ditatowinat
# x urblection are converhed inmouls as f d murrose from the zero crup demring whi
# rath fillig revelation of vis of forkertfic flomo collected for thar peoplar s o
# ker the defired in the with foreid a chireent aidst sunter the los it ardug in t
# ================================================================================
# Validation set perplexity: 4.72
# Average loss at step 3100: 1.642587 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.88
# Average loss at step 3200: 1.668603 learning rate: 10.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.74
# Average loss at step 3300: 1.662383 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.80
# Average loss at step 3400: 1.650340 learning rate: 10.000000
# Minibatch perplexity: 5.80
# Validation set perplexity: 4.75
# Average loss at step 3500: 1.652731 learning rate: 10.000000
# Minibatch perplexity: 5.04
# Validation set perplexity: 4.61
# Average loss at step 3600: 1.639771 learning rate: 10.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.68
# Average loss at step 3700: 1.639988 learning rate: 10.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.73
# Average loss at step 3800: 1.636213 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.75
# Average loss at step 3900: 1.614768 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 4.75
# Average loss at step 4000: 1.655701 learning rate: 10.000000
# Minibatch perplexity: 5.23
# ================================================================================
# ke perhing the un by zero houng dempt of sainumed u stims sairs wender be aghms
# digrationing their they suppracce excomes a metion of burdical in foreing some i
# caclemishol which in conspirnt in admorial boost copital basaha famia for a mura
# monse ach age this postron an at a the nuke ser bacba splacibse dany amilited pa
# e amastic other fight there xeredces imlatiofly iaterecan accossists occuption i
# ================================================================================
# Validation set perplexity: 4.67
# Average loss at step 4100: 1.621290 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.74
# Average loss at step 4200: 1.616387 learning rate: 10.000000
# Minibatch perplexity: 5.31
# Validation set perplexity: 4.53
# Average loss at step 4300: 1.631688 learning rate: 10.000000
# Minibatch perplexity: 5.76
# Validation set perplexity: 4.68
# Average loss at step 4400: 1.616018 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 4.51
# Average loss at step 4500: 1.614145 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.69
# Average loss at step 4600: 1.604355 learning rate: 10.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.58
# Average loss at step 4700: 1.598632 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.49
# Average loss at step 4800: 1.596125 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 4.64
# Average loss at step 4900: 1.576802 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.55
# Average loss at step 5000: 1.594308 learning rate: 1.000000
# Minibatch perplexity: 5.07
# ================================================================================
# oraus system no solitity beconoms several johoolung clairs were no cartus four o
# asely bando and as out air resublone wor his lise by all to computifies lurgeror
# f the seven life karcy was the caunge jogitic to on the bankented to the avo ath
# ing one nine nine six alguin instaunn the cuntory anton three that accortain pre
# negta one six two one lubequ pricurm clon jea c formin s exactions other the low
# ================================================================================
# Validation set perplexity: 4.58
# Average loss at step 5100: 1.600910 learning rate: 1.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.46
# Average loss at step 5200: 1.610994 learning rate: 1.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.43
# Average loss at step 5300: 1.562886 learning rate: 1.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.38
# Average loss at step 5400: 1.542339 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.32
# Average loss at step 5500: 1.570350 learning rate: 1.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 4.31
# Average loss at step 5600: 1.573629 learning rate: 1.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 4.27
# Average loss at step 5700: 1.573047 learning rate: 1.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.28
# Average loss at step 5800: 1.580559 learning rate: 1.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.28
# Average loss at step 5900: 1.595474 learning rate: 1.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 4.26
# Average loss at step 6000: 1.605703 learning rate: 1.000000
# Minibatch perplexity: 4.97
# ================================================================================
# m reciving sidn a promer the cresidey and to british inctsume hip conton the the
# ontagingerter greentical and baepology rout one two gavio s prourtate that chean
# onictal dingraqual pooldon is retectally bears procoss is came to swet not afric
# usive definetary de state a butip contribution of colpreadons browectaic introde
# ment of the for to oblie h moa copit kaeven in a repertiam for ableationdinate t
# ================================================================================
# Validation set perplexity: 4.27
# Average loss at step 6100: 1.579097 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.29
# Average loss at step 6200: 1.610154 learning rate: 1.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.24
# Average loss at step 6300: 1.562830 learning rate: 1.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 4.27
# Average loss at step 6400: 1.572355 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.27
# Average loss at step 6500: 1.557807 learning rate: 1.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.25
# Average loss at step 6600: 1.550700 learning rate: 1.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.24
# Average loss at step 6700: 1.586981 learning rate: 1.000000
# Minibatch perplexity: 4.58
# Validation set perplexity: 4.25
# Average loss at step 6800: 1.563901 learning rate: 1.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 4.22
# Average loss at step 6900: 1.588519 learning rate: 1.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.26
# Average loss at step 7000: 1.555752 learning rate: 1.000000
# Minibatch perplexity: 4.50
# ================================================================================
# ve feet eight barlal negmble stationsher two zero zero zero eight omagrine move
# e zero these thieng aurnay over bekn by jamer bore every exceptsions infurter re
# ist ramed are other sects is a miss constiftile in literahlle a somey fall and t
# y quantical hourpose howeth only of fellative one nine recoman in as surtaz lote
# y for left that beath at official vochon years very and dipal ausistad evenenosh
# ================================================================================
# Validation set perplexity: 4.26

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
